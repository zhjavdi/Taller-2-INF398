# %% [markdown]
# <center><img src="http://www.exalumnos.usm.cl/wp-content/uploads/2015/06/Isotipo-Negro.gif" title="Title text" width="30%" /></center>
#
# <hr style="height:2px;border:none"/>
# <h1 align='center'> INF-398 Aprendizaje Automático </h1>
# <h2 align='center'> La Máquina Alba </h2>
#
# <H3 align='center'> Tarea/Taller 2 </H3>
# <hr style="height:2px;border:none"/>

# %% [markdown]
# # Temas

# %% [markdown]
# * Regresión Lineal
# * Regularización
# * Selección de Características
# * Reducción de Dimensionalidad

# %% [markdown]
# # Reglas & Formalidades
#
# * Pueden trabajar en equipos de 2 a 3 personas.
# * Los equipos deben ser inscritos antes del 10 de Noviembre.
# * Pueden reusar código visto en clases y/o recolectar código/ideas de otros sitios, mencionando al autor y entregando un link a la fuente.
# * Si resulta necesaria, la intervención de personas ajenas al grupo (e.g. experto) debe ser declarada y justificada.
# * Tener roles dentro del equipo está bien, pero al final del proceso, cada miembro debe entender y estar en condiciones de exponer todo el trabajo realizado.

# %% [markdown]
# # Entregables

# %% [markdown]
# > * **Video:** Se debe preparar un video explicativo de **15 a 20 minutos** donde se describe la metodología utilizada, los resultados obtenidos y las conclusiones de la experiencia.
#
# > * **Código:** Se debe enviar un jupyter notebook con el código utilizado, de modo que sea posible **reproducir los resultados** presentados. Como alternativa, se puede entregar un link Github con el código fuente, incluyendo instrucciones precisas para ejecutar los experimentos. En cualquier caso (notebook o repo) el código debe estar ordenado y seccionado apropiadamente.
#
# > * **Conformidad Ética:** Se debe incluir una breve declaración ética en que se indique que el trabajo que se está enviando es un trabajo original, desarollado por los autores en conformidad con todas reglas antes mencionadas. Se debe también mencionar brevemente cuál fue la contribución de cada miembro del equipo. La declaración puede ser parte del notebook o estar en un archivo dentro del repo.
#
# > * **Defensa en vivo (video-conferencia):** El día de clases agendado para la discusión del taller, se seleccionarán aleatoriamente algunos equipos que presentarán oralmente su trabajo ante el curso. Los autores serán evaluados considerando la discusión y debate que generen entre sus pares. Los puntos obtenidos (positivos o negativos) se sumarán a la nota final de taller.

# %% [markdown]
# # Fechas

# %% [markdown]
# > * Defensas: 26 de Noviembre, horario de clases.
# > * Fecha de entrega de vídeo: 27 de Noviembre 23:59 Hrs. (1 días después de encuentro).
# > * Fecha de entrega de Jupyter (notebook): 26 de Noviembre 08:00 (se pueden hacer actualizaciones hasta el 27 de Noviembre 23:59 Hrs.).

# %% [markdown]
# # Instrucciones

# %% [markdown]
# La tarea se divide en dos secciones:
#
#
#
# > **1. Pregunta de Investigación**. Para esta parte, los autores deben elegir una hipótesis de investigación y diseñar un procedimiento experimental que permita reunir evidencia en contra o a favor de la misma. Es legítimo tomar una posición *a-priori* en base a lo que han aprendido en el curso, pero es importante analizar críticamente los resultados sin descartar hipótesis alternativas.
#
# > La metodología debe incluir al menos 3 datasets, de los cuales al menos 2 deben ser reales. Es deseable también que incluyan experimentos controlados sobre dataset sintéticos o semi-sintéticos no triviales diseñados por ustedes. Por ejemplo, para demostrar que un método logra ignorar variables irrelevantes se podrían crear variables "fake" manualmente. Experimentos de este último tipo que se basen en un dataset real contarán como realizados sobre "dataset reales".
#
# > Si no es relevante para la pregunta de investigación y en honor al tiempo, no es necesario llevar a cabo un análisis exploratorio detallado sobre cada dataset utilizado.
#
# >  **2. Desafío Kaggle**. Para esta parte, los autores enfrentarán un desafío en la plataforma Kaggle y serán calificados en base a su posición en el tablero de resultados y el puntaje obtenido.

# %% [markdown]
# # Parte 1. Pregunta de Investigación

# %% [markdown]
# > **12. Reducción de Dimensionalidad**: Combinando el modelo lineal de regresión con PCA perdemos en términos de interpretabilidad pero mejoramos significativamente el error de predicción.

# %% [markdown]
# ## Modelos de Regresión
#
# Los modelos de regresión son ocupadas para predecir valores numéricos, por ejemplo, determinar el precio de una casa a partir de sus metros cuadrados.  Dentro de los modelos de regresión, el modelo más básico (y no por eso menos importante) es el **modelo de regresión lineal**.
#
#
#
# ### Regresión lineal
#
#
#
#
# El **modelo de regresión lineal** supone que,
# $$\boldsymbol{Y} =  \boldsymbol{X}\boldsymbol{\beta} + \boldsymbol{\epsilon},
# $$ donde:
#
# * $\boldsymbol{X} = (x_1,...,x_n)^{T}$: variable explicativa
# * $\boldsymbol{Y} = (y_1,...,y_n)^{T}$: variable respuesta
# * $\boldsymbol{\epsilon} = (\epsilon_1,...,\epsilon_n)^{T}$: error que se asume normal, es decir, $\epsilon \sim \mathcal{N}( \boldsymbol{0},\Sigma)$.
# * $\boldsymbol{\beta} = (\beta_1,...,\beta_n)^{T}$: coeficientes de regresión.
#
#
# La idea es tratar de establecer la relación entre las variables independientes y dependientes por medio de ajustar una mejor línea recta con respecto a los puntos.
#
#
# <center><img src="https://files.realpython.com/media/fig-lin-reg.a506035b654a.png" width="560" height="480"/></center>

# %% [markdown]
# ### Error de un modelo
#
# El **error** corresponde a la diferencia entre el valor original y el valor predicho,es decir:
#
# $$e_{i}=y_{i}-\hat{y}_{i} $$
#
# <center><img src="https://www.jmp.com/en_hk/statistics-knowledge-portal/what-is-multiple-regression/fitting-multiple-regression-model/_jcr_content/par/styledcontainer_2069/par/lightbox_4130/lightboxImage.img.png/1548704005203.png
# " width="480" height="360"/></center>
#
#
# ### Formas de medir el error de un modelo
#
# Para medir el ajuste de un modelo se ocupan las denominadas **funciones de distancias** o **métricas**. Existen varias métricas, dentro de las cuales encontramos:

# %% [markdown]
# 1. **Métricas absolutas**: Las métricas absolutas o no escalada miden el error sin escalar los valores. Las métrica absolutas más ocupadas son:
#
#     *  **Mean Absolute Error** (MAE)
#
#     $$MAE(y,\hat{y})=\frac{1}{n}\sum_{t=1}^{n}\left|y_{t}-\hat{y}_{t}\right|$$
#
#     *  **Mean squared error** (MSE):
#
#     $$MSE(y,\hat{y})=\frac{1}{n}\sum_{t=1}^{n}\left(y_{t}-\hat{y}_{t}\right)^2$$

# %% [markdown]
# 2. **Métricas Porcentuales**: Las métricas porcentuales o escaladas miden el error de manera escalada, es decir, se busca acotar el error entre valores de 0 a 1, donde 0 significa que el ajuste es perfecto, mientras que 1 sería un mal ajuste. Cabe destacar que muchas veces las métricas porcentuales puden tener valores mayores a 1.Las métrica Porcentuales más ocupadas son:
#
#     * **Mean absolute percentage error** (MAPE):
#
#     $$MAPE(y,\hat{y}) = \frac{1}{n}\sum_{t=1}^{n}\left| \frac{y_{t}-\hat{y}_{t}}{y_{t}}\right|,$$
#
#     * **Symmetric mean absolute percentage error** (sMAPE):
#
#     $sMAPE(y,\hat{y}) = \frac{1}{n}\sum_{t=1}^{n} \frac{|y_{t}-\hat{y}-{t}|}{(|y_{t}|^2+|\hat{y}_{t}|^2)/2}$$

# %% [markdown]
# ### R-cuadrado  y  R-cuadrado ajustado
#
#
#
# El **coeficiente de determinación** o **R-cuadrado** ($r^2$ ) , es un estadístico usado en el contexto de un modelo estadístico cuyo principal propósito es predecir futuros resultados o probar una hipótesis. El coeficiente determina la calidad del modelo para replicar los resultados, y la proporción de variación de los resultados que puede explicarse por el modelo.
#
# El valor del $r^2$ habitualmente entre 0 y 1, donde 0 significa una mala calidad de ajuste en el modelo y 1 corresponde a un ajuste lineal perfecto. A menudo, este estadístico es ocupado para modelos lineales.
#
# Se define por la fórmula:
#
#
# $$r^2 = \dfrac{SS_{reg}}{SS_{tot}} = 1 - \dfrac{SS_{res}}{SS_{tot}},$$
#
# donde:
#
# * **$SS_{reg}$** ( suma explicada de cuadrados (ESS)): $\sum_{i}(\hat{y}-\bar{y})^2$
#
#
# * **$SS_{res}$**: ( suma residual de cuadrados (RSS)): $\sum_{i}(y_{i}-\hat{y})^2 = \sum_{i}e_{i}^2$
#
#
# * **$SS_{tot}$**: ( varianza): $\sum_{i}(y_{i}-\bar{y})$, donde: $SS_{tot}=SS_{reg}+SS_{res}$
#
#
# En una forma general, se puede ver que $r^2$ está relacionado con la fracción de varianza inexplicada (FVU), ya que el segundo término compara la varianza inexplicada (varianza de los errores del modelo) con la varianza total (de los datos).
#
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/86/Coefficient_of_Determination.svg/400px-Coefficient_of_Determination.svg.png
# " width="480" height="360" align="rigt"/>
#
#
# * Las áreas de los cuadrados azules representan los residuos cuadrados con respecto a la regresión lineal ($SS_{tot}$).
#
# * Las áreas de los cuadrados rojos representan los residuos al cuadrado con respecto al valor promedio ($SS_{res}$).
#
#
#
# Por otro lado, a medida que más variables explicativas se agregan al modelo, el $r^2$ aumenta de forma automática, es decir, entre más variables explicativas se agreguen, mejor será la calidad será el ajuste (un falso argumento).
#
#
#
# Es por ello que se define el **$r^2$ ajustado**, que viene a ser  una modificación del $r^2$, ajustando por el número de variables explicativas en un modelo ($p$) en relación con el número de puntos de datos ($n$).
#
#
# $$r^2_{ajustado} = 1-(1-r^2)\dfrac{n-1}{n-p-1} ,$$

# %% [markdown]
# ### Método de minimos cudrados
#
# El **método de mínimos cudrados** es un método de optimización que busca encontrar la mejor aproximación mediante la minimización de los residuos al cuadrado, es decir, se buscar encontrar:
#
# $$(P)\ \min \sum_{i=1}^n e_{i}^2 =\sum_{i=1}^n (y_{i}-f_{i}(x;\beta))^2   $$
#
# Para el caso de la regresión lineal simple, se busca una función $$f(x;\beta) = \beta_{0} + \beta_{1}x,$$
#
# por lo tanto el problema que se debe resolver es el siguiente:
#
# $$(P)\ \min \sum_{i=1}^n e_{i}^2 =\dfrac{1}{n}\sum_{i=1}^{n}\left ( y_{i}-(\beta_{0} + \beta_{1}x_{i})\right )^2$$
#
# Lo que significa, que para este problema, se debe encontrar $\beta = (\beta_{0},\beta_{1})$ que minimicen el problema de optimización. En este caso la solución viene dada por:
#
# $$\hat{\beta}_{1} = \dfrac{\sum(x-\bar{x})(y-\bar{y})}{\sum(x-\bar{x})^2} = \rho (x,y)\ ; \  \hat{\beta}_{0} = \bar{y}-\hat{\beta}_{1} \bar{x} $$

# %% [markdown]
# La metodología para encontrar los parámetros $\beta$ para el caso de la regresión lineal multiple se extienden de manera natural del modelo de regresión lineal multiple, cuya solución viene dada por:
#
# $$\beta = (XX^{\top})^{-1}X^{\top}y$$

# %% [markdown]
# **IMPORTANTE**:
#
#
# * Cabe destacar que el coeficiente $r^2$ funciona bien en el contexto del mundo de las regresiones lineales. Para el análisis de **modelos no lineales**, esto coeficiente pierde su interpretación.
#
#
# * Se deja la siguiente [referencia](http://reliawiki.org/index.php/Simple_Linear_Regression_Analysis) para comprender conceptos claves de test de hipótesis, intervalos de confianza, p-valor. Estos términos son escenciales para comprender la significancia del ajuste realizado.
#
#
# * Existen muchas más métricas, pero estas son las más usulaes de encontrar.

# %% [markdown]
# ## Análisis de componentes principales
#
#
# El **análisis de componentes principales** (PCA) es un procedimiento estadístico que utiliza una transformación ortogonal para convertir un conjunto de observaciones de variables posiblemente correlacionadas (entidades que adquieren varios valores numéricos) en un conjunto de valores de variables linealmente no correlacionadas llamadas componentes principales.
#
# Esta transformación se define de tal manera que el primer componente principal tiene la mayor varianza posible (es decir, representa la mayor variabilidad posible en los datos), y cada componente subsiguiente a su vez tiene la mayor varianza posible bajo la restricción que es ortogonal a los componentes anteriores.
#
# Los vectores resultantes (cada uno de los cuales es una combinación lineal de las variables y contiene n observaciones) son un conjunto de bases ortogonales no correlacionadas. PCA es sensible a la escala relativa de las variables originales.
#
# <center><img alt="Series de tiempo con Python" title="Series de tiempo con Python" src="https://devopedia.org/images/article/139/4543.1548137789.jpg" high=400px width=600px></center>

# %% [markdown]
# # Problema 1

# %% [markdown]
# Este desafío propuesto por Dean De Cock tiene el objetivo de predecir el valor de una vivienda en base a diversos atributos. Puede encontrar una descripción más detallada aquí: [https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview).

# %% [markdown]
# ## Exploratorio

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score

# %%
#print("Mounting your Google Drive ...")

#from google.colab import drive
#drive.flush_and_unmount()
#drive.mount('/content/drive',force_remount=True)
 
#path = "/content/drive/My Drive/clases-II-2021/Machine-Learning/datasets/taller02/"#Esta es la ruta
path = "nomades-digitales/"

name = 'train.csv' 
name2 = 'test.csv'

# %%
data_train = pd.read_csv(path+name,encoding='latin-1', index_col = 0)
data_train = data_train.dropna(axis=1)
data_train = data_train.sample(n=10000,replace=True)
data_train.head()
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1412          50       RL     9600   Pave      Reg         Lvl    AllPub
# 1436          20       RL     8400   Pave      Reg         Lvl    AllPub
# 583           90       RL    11841   Grvl      Reg         Lvl    AllPub
# 405           60       RL    10364   Pave      IR1         Lvl    AllPub
# 756          160       FV     3230   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# Id                                     ...
# 1412    Inside       Gtl        NAmes  ...             0         0
# 1436    Inside       Gtl        NAmes  ...             0         0
# 583     Inside       Gtl      Edwards  ...             0         0
# 405     Inside       Gtl      Gilbert  ...             0         0
# 756     Inside       Gtl      Somerst  ...             0         0
#
# ...

# %%
data_train.shape
# Out:
# (10000, 61)

# %%
#data = data_train.dropna()
data = data_train.drop_duplicates()
print(data.shape)
data.head()
# Out:
# (1459, 61)
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1412          50       RL     9600   Pave      Reg         Lvl    AllPub
# 1436          20       RL     8400   Pave      Reg         Lvl    AllPub
# 583           90       RL    11841   Grvl      Reg         Lvl    AllPub
# 405           60       RL    10364   Pave      IR1         Lvl    AllPub
# 756          160       FV     3230   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# Id                                     ...
# 1412    Inside       Gtl        NAmes  ...             0         0
# 1436    Inside       Gtl        NAmes  ...             0         0
# 583     Inside       Gtl      Edwards  ...             0         0
# 405     Inside       Gtl      Gilbert  ...             0         0
# 756     Inside       Gtl      Somerst  ...             0         0
#
# ...

# %%
cont_predictor_names = [] # continuous variables
cat_predictor_names = [] # categorical variables

for column in data.columns[:60]:
    if data[column].dtype == 'object':
        cat_predictor_names.append(column)
    else:
        cont_predictor_names.append(column)

print('Continuous variables:')
print(cont_predictor_names)
print('')
print('Categorical variables:')
print(cat_predictor_names)
# Out:
# Continuous variables:
# ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
#
# Categorical variables:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating', 'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
for column in cat_predictor_names:
    print(column)
    print(data[column].unique())
    print('')
print(len(cat_predictor_names))
# Out:
# MSZoning
# ['RL' 'FV' 'RH' 'RM' 'C (all)']
#
# Street
# ['Pave' 'Grvl']
#
# LotShape
# ['Reg' 'IR1' 'IR3' 'IR2']
#
# LandContour
# ['Lvl' 'Bnk' 'HLS' 'Low']
#
# Utilities
# ['AllPub' 'NoSeWa']
#
# LotConfig
# ['Inside' 'CulDSac' 'Corner' 'FR2' 'FR3']
#
# LandSlope
# ['Gtl' 'Mod' 'Sev']
#
# Neighborhood
# ['NAmes' 'Edwards' 'Gilbert' 'Somerst' 'Sawyer' 'NridgHt' 'CollgCr'
#  'SWISU' 'Mitchel' 'BrkSide' 'IDOTRR' 'Crawfor' 'Veenker' 'SawyerW'
#  'Timber' 'NoRidge' 'NWAmes' 'OldTown' 'MeadowV' 'StoneBr' 'NPkVill'
#  'Blmngtn' 'ClearCr' 'Blueste' 'BrDale']
#
# Condition1
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAn' 'PosA' 'RRNn' 'RRAe' 'RRNe']
#
# Condition2
# ['Norm' 'PosN' 'Feedr' 'RRAe' 'RRNn' 'Artery' 'RRAn' 'PosA']
#
# BldgType
# ['1Fam' 'Duplex' 'TwnhsE' 'Twnhs' '2fmCon']
#
# HouseStyle
# ['1.5Fin' '1Story' 'SFoyer' '2Story' '1.5Unf' 'SLvl' '2.5Unf' '2.5Fin']
#
# RoofStyle
# ['Gable' 'Flat' 'Hip' 'Shed' 'Mansard' 'Gambrel']
#
# RoofMatl
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

predictor_names = cont_predictor_names
n_show = min(len(predictor_names),50)

corrmat = data[predictor_names[:n_show]].corr()
fig, ax = plt.subplots(figsize=(13, 13))
sns.heatmap(corrmat, vmax=.9, square=True, ax=ax, cmap='PiYG_r')
ax.set_title("Correlación Lineal Predictores vs Predictores")
plt.show()

# %%
# definimos el dataframe con variables numéricas

df_cont = data.drop(cat_predictor_names, axis=1)
df_cont.head()
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1412          50     9600            6            8       1950          2005
# 1436          20     8400            6            9       1962          2005
# 583           90    11841            6            5       1990          1990
# 405           60    10364            6            5       1995          1996
# 756          160     3230            6            5       1999          1999
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# Id                                                    ...
# 1412         120           0        736          856  ...           0
# 1436           0           0       1319         1319  ...           0
# 583          816           0          0          816  ...           0
# 405            0           0        806          806  ...           0
# 756          381           0        348          729  ...           0
#
# ...

# %%
# reemplazamos los valores NaN por la media de la columna
for column in df_cont.columns:
    if df_cont[column].notnull().all() == False:
        df_cont = df_cont.fillna(df_cont[column].mean())

# %%
from sklearn.preprocessing import MinMaxScaler

# normalizamos con MinMaxScaler

scaler = MinMaxScaler()
df_cont[cont_predictor_names] = scaler.fit_transform(df_cont[cont_predictor_names])

df_cont.head()
# Out:
#       MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1412    0.176471  0.038795     0.555556        0.875   0.565217      0.916667
# 1436    0.000000  0.033186     0.555556        1.000   0.652174      0.916667
# 583     0.411765  0.049270     0.555556        0.500   0.855072      0.666667
# 405     0.235294  0.042366     0.555556        0.500   0.891304      0.766667
# 756     0.823529  0.009021     0.555556        0.500   0.920290      0.816667
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# Id                                                    ...
# 1412    0.021262         0.0   0.315068     0.140098  ...         0.0
# 1436    0.000000         0.0   0.564640     0.215876  ...         0.0
# 583     0.144578         0.0   0.000000     0.133552  ...         0.0
# 405     0.000000         0.0   0.345034     0.131915  ...         0.0
# 756     0.067505         0.0   0.148973     0.119313  ...         0.0
#
# ...

# %%
# creamos el dataframe con variables categóricas

df_cat = data.drop(cont_predictor_names, axis=1)
df_cat.head()
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1412       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1436       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 583        RL   Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 405        RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 756        FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Foundation Heating HeatingQC  \
# Id                                       ...
# 1412        NAmes       Norm       Norm  ...     CBlock    GasA        Ex
# 1436        NAmes       Norm       Norm  ...     CBlock    GasA        TA
# 583       Edwards       Norm       Norm  ...     CBlock    GasA        TA
# 405       Gilbert       Norm       Norm  ...      PConc    GasA        Gd
# 756       Somerst       Norm       Norm  ...      PConc    GasA        Gd
#
# ...

# %%
from sklearn.dummy import DummyClassifier

# utilizamos get_dummies para transformar los valores categóricos a valores numéricos

df_cat_dummies = pd.get_dummies(df_cat)
df_cat_dummies.head()
# Out:
#       SalePrice  MSZoning_C (all)  MSZoning_FV  MSZoning_RH  MSZoning_RL  \
# Id
# 1412     140000                 0            0            0            1
# 1436     174000                 0            0            0            1
# 583      118500                 0            0            0            1
# 405      168000                 0            0            0            1
# 756      172500                 0            1            0            0
#
#       MSZoning_RM  Street_Grvl  Street_Pave  LotShape_IR1  LotShape_IR2  ...  \
# Id                                                                       ...
# 1412            0            0            1             0             0  ...
# 1436            0            0            1             0             0  ...
# 583             0            1            0             0             0  ...
# 405             0            0            1             1             0  ...
# ...

# %%
# definimos el dataframe procesado usando el comando join

df_procesado = df_cont.join(df_cat_dummies.drop(['SalePrice'],axis=1))
df_procesado.head()
# Out:
#       MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1412    0.176471  0.038795     0.555556        0.875   0.565217      0.916667
# 1436    0.000000  0.033186     0.555556        1.000   0.652174      0.916667
# 583     0.411765  0.049270     0.555556        0.500   0.855072      0.666667
# 405     0.235294  0.042366     0.555556        0.500   0.891304      0.766667
# 756     0.823529  0.009021     0.555556        0.500   0.920290      0.816667
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  SaleType_ConLw  \
# Id                                                    ...
# 1412    0.021262         0.0   0.315068     0.140098  ...               0
# 1436    0.000000         0.0   0.564640     0.215876  ...               0
# 583     0.144578         0.0   0.000000     0.133552  ...               0
# 405     0.000000         0.0   0.345034     0.131915  ...               0
# ...

# %%
df_procesado.describe()
# Out:
#         MSSubClass      LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1459.000000  1459.000000  1459.000000  1459.000000  1459.000000
# mean      0.216788     0.043100     0.566598     0.571967     0.719174
# std       0.248722     0.046663     0.153719     0.139135     0.218854
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.029255     0.444444     0.500000     0.594203
# 50%       0.176471     0.038234     0.555556     0.500000     0.731884
# 75%       0.294118     0.048157     0.666667     0.625000     0.927536
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  ...  \
# count   1459.000000  1459.000000  1459.000000  1459.000000  1459.000000  ...
# mean       0.580889     0.078578     0.031602     0.242936     0.173089  ...
# std        0.344117     0.080833     0.109478     0.189173     0.071820  ...
# ...

# %% [markdown]
# ## El Regresor Lineal

# %%
from sklearn.metrics import r2_score

def mae(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute error (MAE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.abs(error).mean(), 4)


def mse(targets, predictions) -> float:
    """
    Calculo de la metrica: mean squared error (MSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round((error ** 2).mean(), 4)


def rmse(targets, predictions) -> float:
    """
    Calculo de la metrica: root mean squared error (RMSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.sqrt((error ** 2).mean()), 4)


# b) Percentage errors

def mape(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute percentage error (MAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets

    if any(x == 0 for x in targets):
        return np.inf
    else:
        return round(np.abs(error / targets).mean(),4)


def maape(targets, predictions) -> float:
    """
    Calculo de la metrica:  mean arctangent percentage error  (MAAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """

    error = predictions - targets

    if any((x, y) == (0, 0) for x, y in zip(predictions, targets)):
        return np.inf

    else:
        return round(np.arctan(np.abs(error / targets)).mean(),4)


def wmape(targets, predictions) -> float:
    """
    Calculo de la metrica:  weighted mean absolute percentage error (WMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.sum(targets)

    if sum_values == 0:
        return np.inf
    else:
        return round(np.abs(error).sum() / sum_values,4)


def mmape(targets, predictions) -> float:
    """
    Calculo de la metrica: modified mean absolute percentage error (MMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = np.abs(predictions - targets)
    denom = 1 + np.abs(targets)

    return round(np.mean(error / denom),4)


def smape(targets, predictions) -> float:
    """
    Calculo de la metrica: symmetric mean absolute percentage error (SMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.abs(predictions) + np.abs(targets)

    if any(x == 0 for x in sum_values):
        return np.inf

    else:
        return round(2 * np.mean(np.abs(error) / sum_values),4)

def summary_metrics(df) -> pd.DataFrame:
    """
    Aplicar las distintas metricas definidas
    :param df:  dataframe con las columnas: ['y','yhat']
    :return: dataframe con las metricas especificadas
    """
    df_result = pd.DataFrame()

    y_true = df['y']
    y_pred = df['yhat']

    df_result['mae'] = [round(mae(y_true, y_pred), 4)]
    df_result['mse'] = [round(mse(y_true, y_pred), 4)]
    df_result['rmse'] = [round(rmse(y_true, y_pred), 4)]

    df_result['mape'] = [round(mape(y_true, y_pred), 4)]
    df_result['maape'] = [round(maape(y_true, y_pred), 4)]
    df_result['wmape'] = [round(wmape(y_true, y_pred), 4)]
    df_result['mmape'] = [round(mmape(y_true, y_pred), 4)]
    df_result['smape'] = [round(smape(y_true, y_pred), 4)]

    df_result['r2'] = [round(r2_score(y_true,y_pred),4)]

    return df_result

# %%
#Se utilizan las componentes proyectadas
from sklearn import preprocessing
from sklearn import utils
from sklearn.model_selection import train_test_split

X = df_procesado.drop(['SalePrice'],axis=1)
y = df_procesado[['SalePrice']]

#Se normaliza con Standard Scaler
#X = StandardScaler().fit_transform(X)

#Se normaliza con LabelEncoder
lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y)
y = encoded

#Se crean los conjuntos de entrenamiento y test desde los conjuntos definidos anteriormente
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 2)

# %%
clf = LinearRegression().fit(X, y)

y_predict_train_clf = clf.predict(X_train)
enc_pred_train = lab_enc.fit_transform(y_predict_train_clf)
y_predict_train_clf = enc_pred_train

y_predict_test_clf = clf.predict(X_test)
enc_pred_test = lab_enc.fit_transform(y_predict_test_clf)
y_predict_test_clf = enc_pred_test

# %% [markdown]
# ## Principal Component Analysis en el Regresor Lineal

# %%
X = df_procesado.drop(['SalePrice'],axis=1)
y = df_procesado[['SalePrice']]

#Se normaliza con Standard Scaler
#X = StandardScaler().fit_transform(X)

n = 45

columns=[]
for i in range(n): 
    columns.append('PC'+str(i+1))

pca = PCA(n_components=n) #Modelo, se tomarán 50 n-componentes, es decir, se tomarán 50 variables para reducir la dimensión
principalComponents = pca.fit_transform(X) #fit del modelo

principalDataframe = pd.DataFrame(data = principalComponents, columns = columns)
principalDataframe.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.443641  0.302295 -0.207217 -0.093564 -1.215445  0.131978 -0.355393
# 1 -0.201568 -0.300638 -0.720779  0.169607  0.409852 -0.553488  0.129240
# 2 -1.536267 -0.017887  0.149114 -1.202669 -0.151554 -0.171812  0.167867
# 3 -0.188569  0.122563  1.212044 -0.084267  0.168372  0.216287  0.547082
# 4 -0.318853  1.560724  0.403641 -1.039553  0.721588 -0.117184  0.696316
#
#         PC8       PC9      PC10  ...      PC36      PC37      PC38      PC39  \
# 0 -0.952371  0.416714 -0.501376  ... -0.058727 -0.123386 -0.051611  0.309604
# 1  0.922612 -0.431021 -1.724855  ...  0.121520  0.074055 -0.115833 -0.152183
# 2  0.375634  0.005561  0.153930  ... -0.658412 -0.080091 -0.225122 -0.269041
# 3 -1.403068 -0.107260  0.053891  ...  0.086772  0.242903  0.149974 -0.023118
# 4 -0.700645  0.413480  0.517329  ...  0.211403  0.155803  0.146645  0.363046
#
#        PC40      PC41      PC42      PC43      PC44      PC45
# ...

# %%
y = y.reset_index()

df_reducido = pd.concat([principalDataframe, y],axis = 1)
df_reducido.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.443641  0.302295 -0.207217 -0.093564 -1.215445  0.131978 -0.355393
# 1 -0.201568 -0.300638 -0.720779  0.169607  0.409852 -0.553488  0.129240
# 2 -1.536267 -0.017887  0.149114 -1.202669 -0.151554 -0.171812  0.167867
# 3 -0.188569  0.122563  1.212044 -0.084267  0.168372  0.216287  0.547082
# 4 -0.318853  1.560724  0.403641 -1.039553  0.721588 -0.117184  0.696316
#
#         PC8       PC9      PC10  ...      PC38      PC39      PC40      PC41  \
# 0 -0.952371  0.416714 -0.501376  ... -0.051611  0.309604  0.370920  0.126521
# 1  0.922612 -0.431021 -1.724855  ... -0.115833 -0.152183  0.265485  0.395943
# 2  0.375634  0.005561  0.153930  ... -0.225122 -0.269041  0.119033 -0.166846
# 3 -1.403068 -0.107260  0.053891  ...  0.149974 -0.023118  0.314919 -0.166014
# 4 -0.700645  0.413480  0.517329  ...  0.146645  0.363046  0.015174  0.064531
#
#        PC42      PC43      PC44      PC45    Id  SalePrice
# ...

# %%
#Se utilizan las componentes proyectadas
from sklearn import preprocessing
from sklearn import utils
from sklearn.model_selection import train_test_split

X = df_reducido[columns]
Y = df_reducido['SalePrice']

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(Y)
Y = encoded

#Se crean los conjuntos de entrenamiento y test desde los conjuntos definidos anteriormente
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state = 2)

# %%
clf = LinearRegression().fit(X, Y)

Y_predict_train_pca = clf.predict(X_train)
enc_pred_train = lab_enc.fit_transform(Y_predict_train_pca)
Y_predict_train_pca = enc_pred_train

Y_predict_test_pca = clf.predict(X_test)
enc_pred_pca = lab_enc.fit_transform(Y_predict_test_pca)
Y_predict_test_pca = enc_pred_pca

# %%
#Varianzas por n-componentes
percent_variance = np.round(pca.explained_variance_ratio_, decimals =3)

plt.figure(figsize=(15,7))
plt.bar(x= range(1,n+1), height=percent_variance, tick_label=columns)
plt.xticks(x= range(1,n+1), rotation='vertical')
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %%
# Gráfico de Varianza acumulada entre las n-componentes
percent_variance_cum = np.cumsum(percent_variance)

plt.figure(figsize=(15,7))
plt.bar(x= range(1,n+1), height=percent_variance_cum, tick_label=columns)
plt.xticks(x= range(1,n+1), rotation='vertical')
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component Cumsum')
plt.title('PCA Scree Plot')
plt.show()

# %% [markdown]
# ## Comparación

# %%
pd.concat([summary_metrics(pd.DataFrame(data={'y':y_test, 'yhat':y_predict_test_clf})),summary_metrics(pd.DataFrame(data={'y':Y_test, 'yhat':Y_predict_test_pca}))], keys=['LinReg model', 'LinReg model + PCA'])
# Out:
#                           mae        mse     rmse  mape   maape   wmape  \
# LinReg model       0  58.2697  5340.9917  73.0821   inf  0.2290  0.1991
# LinReg model + PCA 0  67.7967  7246.7427  85.1278   inf  0.2669  0.2316
#
#                        mmape   smape      r2
# LinReg model       0  0.2565  0.2938  0.8148
# LinReg model + PCA 0  0.3433  0.3471  0.7487

# %% [markdown]
# Un modelo lineal ordinario obtiene un RMSE (en escala original) de
#
# *   TEST: 82.62 (usando solo el modelo de Regresión Lineal)
# *   TEST: 93.39 (usando PCA)
#
# Si en cambio nos interesa el error relativo y medimos el MAPE
#
# *   TEST: 0.24 (usando solo el modelo de Regresión Lineal)
# *   TEST: 0.28 (usando PCA)

# %% [markdown]
# # Problema 2

# %% [markdown]
# El envejecimiento es una de esas certezas incómodas e inevitables que nos recuerdan que, hagamos lo que hagamos, vivamos como vivamos, estamos limitados por nuestro cuerpo biológico y destinados a morir (?). Pero, ¿envejecemos todos a la misma velocidad? *¿Podemos medir objetivamente la edad biológica de una persona?* En este problema trabajaremos con datos de una investigación en que se busca identificar biomarcadores de envejecimiento.

# %% [markdown]
# <center><img  src="https://cdn.psychologytoday.com/sites/default/files/field_blog_entry_images/aging-research.jpg" title="Title text" width="60%" height="60%"/></center>

# %% [markdown]
# ## Exploratorio

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
#print("Mounting your Google Drive ...")

#from google.colab import drive
#drive.flush_and_unmount()
#drive.mount('/content/drive',force_remount=True)
 
#path = "/content/drive/My Drive/clases-II-2021/Machine-Learning/datasets/taller02/"#Esta es la ruta
path = "nomades-digitales/"

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

name = 'rna_data_edad_normal.csv' 

data = pd.read_csv(path+name,header=0,engine='python') #tiene header y separa con tab

predictor_names = [name for name in data.columns if name != 'Age' and name != 'subject']
not_numerical = []
print("Predictors", predictor_names)
# Out:
# Predictors ['MPV17L', 'AFF4', 'ZGLP1', 'LOC105373021', 'GABPB1-AS1', 'CHDH', 'C12orf74', 'MIR6801', 'ZFP90', 'KDM6B', 'DCLRE1A', 'LOC440461', 'SPINK2', 'NSUN5P2', 'LRRC3C', 'P2RY14', 'SC5D', 'DSN1', 'LINC01523', 'LOC105370941', 'KCP', 'SKP1', 'LINC00965', 'ADAMTS9', 'PRPF3', 'PARP14', 'CCDC9', 'LOC440934', 'HOXB1', 'TM7SF2', 'CDV3', 'NELFA', 'ARHGEF19', 'P2RX3', 'LINC00583', 'UBR5', 'SBDSP1', 'COASY', 'AP1S3', 'AP2M1', 'SPDYE3', 'DGUOK', 'FAM160B1', 'TMEM88B', 'RAP2B', 'GSDMC', 'FAIM', 'ABCC6', 'C1QTNF9B-AS1', 'CRABP2', 'C1orf61', 'CARD16', 'LINC00207', 'CYMP-AS1', 'SULT1C3', 'LTV1', 'AICDA', 'SGIP1', 'PALM2-AKAP2', 'ABCC3', 'DAZAP2', 'TNFRSF14', 'ZNF7', 'SLC22A5', 'CDK3', 'LOC105379183', 'KLKP1', 'PRKACG', 'NAA40', 'SCN5A', 'PIP4K2B', 'LOC101927069', 'BLMH', 'LOC101928495', 'SGPP1', 'LOC101928540', 'MIR215', 'S1PR5', 'SELENOV', 'ABL2', 'IKZF3', 'U2SURP', 'MIR661', 'INSC', 'CPT2', 'NT5C1B', 'CHRNA3', 'UBQLN3', 'ZNF71', 'MCM3AP', 'HIST2H2BF', 'LTN1', 'CEBPZOS', 'LINC01056', 'LOC100507
# ...

# %%
print(data.columns)
data.head()
# Out:
# Index(['subject', 'MPV17L', 'AFF4', 'ZGLP1', 'LOC105373021', 'GABPB1-AS1',
#        'CHDH', 'C12orf74', 'MIR6801', 'ZFP90',
#        ...
#        'TCEAL2', 'PNPLA5', 'LINC01055', 'RUFY3', 'FGFRL1', 'GALNT8', 'CCNG2',
#        'LOC646762', 'SLC25A48', 'Age'],
#       dtype='object', length=27144)
#                            subject  MPV17L    AFF4  ZGLP1  LOC105373021  \
# 0  101_19yr_Female_Caucasian/ FPKM   0.133  16.980  0.387          0.00
# 1    102_19yr_Male_Caucasian/ FPKM   0.213  16.772  0.168          0.00
# 2    103_19yr_Male_Caucasian/ FPKM   0.054  16.206  0.410          0.00
# 3    104_19yr_Male_Caucasian/ FPKM   0.066  15.345  0.148          0.00
# 4    105_20yr_Male_Caucasian/ FPKM   0.156  16.873  0.252          0.09
#
#    GABPB1-AS1   CHDH  C12orf74  MIR6801  ZFP90  ...  TCEAL2  PNPLA5  \
# 0       0.626  0.115         0   31.531  5.500  ...   0.000   0.000
# 1       0.701  0.077         0   27.992  6.473  ...   0.000   0.000
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5),nrows=1)
sns.distplot(data['Age'])
ax.set_title('Distribución de la Edad')
plt.show()

print("\n")
print("Shape:", data.shape)
# Out:
# Shape: (133, 27144)

# %% [markdown]
# ### Distribución conjunta Predictores vs Respuesta

# %%
np.random.shuffle(predictor_names)
n_show = min(len(predictor_names),12)

fig, axes = plt.subplots(figsize=(16,4*int(np.ceil(n_show/4))), nrows=int(np.ceil(n_show/4)), ncols=4)
for i,  column in enumerate(predictor_names[:n_show]):
  #sns.distplot(data[column], hist=True, rug=False, kde=True, ax=axes[i//4,i%4],label=column)
  #sns.kdeplot(x=data[column], y=data['Age'],ax=axes[i//4,i%4])
  sns.scatterplot(data=data,x=column, y='Age',ax=axes[i//4,i%4])
  i = i+1
plt.show()

# %% [markdown]
# ### Correlaciones

# %% [markdown]
# #### Correlaciones entre Predictores

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

n_show = min(len(predictor_names),50)

corrmat = data[predictor_names[:n_show]].corr()
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=.9, square=True, ax=ax,cmap="Blues")
ax.set_title("Correlación Lineal Predictores vs Predictores")
plt.show()

# %% [markdown]
# #### Correlaciones entre Predictores y Respuesta

# %% [markdown]
# Calculamos la correlación lineal (pearson) entre los predictores y la respuesta, ordenando los resultados de menor a mayor por magnitud absoluta. Como existen predictores irregulares (constantes) en el dataset algunos de estos valores de correlación podrían ser NAN.

# %%
corrmat = data[predictor_names].corrwith(data['Age'], axis=0, method='pearson')
corrmat = corrmat[~corrmat.isna()]
corrmat = corrmat.reset_index(drop=False).rename(columns={'index': 'name'})
print(corrmat.columns)
corrmat = corrmat.rename(columns={0: "rho",})
corrmat['abs_rho'] = np.abs(corrmat['rho'])
corrmat = corrmat.sort_values(by=['abs_rho'])
# Out:
# Index(['name', 0], dtype='object')

# %% [markdown]
# Sólo para explorar el dataset, mostramos las correlaciones lineales más fuertes y más débiles.

# %%
n_show = min(len(predictor_names),25)

plot_corrmat = corrmat.iloc[-n_show:,:].copy()

print("\nTop Correlations")
fig, ax = plt.subplots(figsize=(10,6*int(np.ceil(n_show/25))))
sns.barplot(x=plot_corrmat.rho,y=plot_corrmat.name,orient='h',ax=ax)
#ax.set_yticklabels(predictor_names[:n_show])
ax.set_title("Correlación Lineal Predictores vs Y")
plt.show()

plot_corrmat = corrmat.iloc[:n_show,:].copy()

print("\nWeakest Correlations")
fig, ax = plt.subplots(figsize=(10,6*int(np.ceil(n_show/25))))
sns.barplot(x=plot_corrmat.rho,y=plot_corrmat.name,orient='h',ax=ax)
#ax.set_yticklabels(predictor_names[:n_show])
ax.set_title("Correlación Lineal Predictores vs Y")
plt.show()
# Out:
# Top Correlations
# Weakest Correlations

# %% [markdown]
# ### Boxplots

# %%
n_show = min(len(predictor_names),12)

fig, axes = plt.subplots(figsize=(16,3.5*int(np.ceil(n_show/6))), nrows=int(np.ceil(n_show/6)), ncols=6)
for i, column in enumerate(predictor_names[:n_show]):
      sns.boxplot(x=data[column],ax=axes[i//6,i%6])
      axes[i//6,i%6].set_xlabel("")
      axes[i//6,i%6].set_title(column)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Pre-procesamiento

# %% [markdown]
# ### Predictores Anormales

# %% [markdown]
# Este paso elimina los predictores que son aproximadamente constantes en el dataset o aquellos que presenta una gran cantidad de outliers extremos.

# %%
Q1 = data[predictor_names].quantile(0.25)
Q3 = data[predictor_names].quantile(0.75)
IQR = Q3 - Q1

print("Original Shape", data.shape)
filtered = np.array((IQR < 0.0001).values)

filtered_names = [predictor_names[idx] for idx in range(len(predictor_names)) if filtered[idx]]
survided_names = [predictor_names[idx] for idx in range(len(predictor_names)) if not filtered[idx]]

fitered_as_constants = filtered_names

data_filtered = data.copy()
data_filtered = data_filtered.drop(filtered_names,axis=1)
print("After Filtering", data_filtered.shape)

print("Deleted: ", len(filtered_names), "App. Constant Variables")

Q1 = data_filtered[survided_names].quantile(0.25)
Q3 = data_filtered[survided_names].quantile(0.75)
IQR = Q3 - Q1

f_outliers = ((data_filtered < (Q1 - 1.5 * IQR)) | (data_filtered > (Q3 + 1.5 * IQR))).sum()
f_outliers = f_outliers/len(data_filtered)

new_survived_names = [survided_names[idx] for idx in range(len(survided_names)) if f_outliers[survided_names[idx]]<0.2]
new_filtered_names = [survided_names[idx] for idx in range(len(survided_names)) if f_outliers[survided_names[idx]]>=0.2]

print("Deleted: ",len(new_filtered_names), "Variables with >20% outliers")

new_data_filtered = data_filtered.copy()
new_data_filtered = data_filtered.drop(new_filtered_names,axis=1)
print("After Second Filtering", new_data_filtered.shape)

fitered_by_outliers = new_filtered_names
# Out:
# Original Shape (133, 27144)
# After Filtering (133, 18010)
# Deleted:  9134 App. Constant Variables
# Deleted:  9 Variables with >20% outliers
# After Second Filtering (133, 18001)

# %% [markdown]
# ### Apply Filtering (no se puede deshacer)

# %%
#data = data_filtered
#predictor_names = survided_names

# %%
data = new_data_filtered
predictor_names = new_survived_names
print(predictor_names)
# Out:
# ['COL8A2', 'KRT38', 'PRKAB2', 'GLDN', 'EAF2', 'LOC644936', 'ABHD16A', 'RPL35A', 'SQLE', 'CGB8', 'ACTG1', 'MXRA8', 'SMARCA2', 'PTMA', 'MYO18A', 'LOC643542', 'MID1', 'ZNF226', 'RIC1', 'TSC22D1-AS1', 'LRRC37B', 'ZNF410', 'LINC00312', 'COQ2', 'SNORD78', 'COX5A', 'SMPD1', 'SORBS1', 'UBE2O', 'HSD11B2', 'UROS', 'MOCS1', 'TBCE', 'MARCKSL1', 'MIR3605', 'MIR4745', 'REXO4', 'RHNO1', 'LMNB2', 'PINLYP', 'CPT1B', 'TMEM233', 'AKAP8L', 'CBWD3', 'PDCD6IPP2', 'LOC254896', 'MRPS22', 'HHAT', 'GABRQ', 'MRPL40', 'TUBA1A', 'EYA4', 'LRRIQ4', 'FASN', 'GTF2E1', 'AHNAK2', 'RAP2C-AS1', 'MYO1C', 'SNRPD1', 'CD3EAP', 'FAM175A', 'CCDC3', 'SNORA29', 'SMCO2', 'LRRN4', 'SLC20A1', 'CXCL2', 'ATP7B', 'BTAF1', 'SCNN1A', 'GRINA', 'ATP6V0A4', 'LRP2BP', 'MYLK3', 'OR1J2', 'SDHAF4', 'NUDT17', 'FAM179A', 'ZCCHC11', 'HHIPL1', 'SPOCK2', 'SNORD116-4', 'ALMS1', 'KIAA1147', 'MXRA5', 'LOC105370333', 'ADAMTSL2', 'CLTB', 'FARP1', 'ACTA1', 'DDX17', 'YTHDC1', 'C16orf62', 'WASF3', 'MAP3K9', 'CYB5R4', 'TLDC2', 'PDP2', 'TROAP', 'ESR2', 'ZNF
# ...

# %%
data.head()
# Out:
#                            subject  MPV17L    AFF4  ZGLP1  GABPB1-AS1   CHDH  \
# 0  101_19yr_Female_Caucasian/ FPKM   0.133  16.980  0.387       0.626  0.115
# 1    102_19yr_Male_Caucasian/ FPKM   0.213  16.772  0.168       0.701  0.077
# 2    103_19yr_Male_Caucasian/ FPKM   0.054  16.206  0.410       1.135  0.284
# 3    104_19yr_Male_Caucasian/ FPKM   0.066  15.345  0.148       0.685  0.304
# 4    105_20yr_Male_Caucasian/ FPKM   0.156  16.873  0.252       0.806  0.094
#
#    MIR6801  ZFP90  KDM6B  DCLRE1A  ...  GAS2L2   BPHL   PCNX4  FAM45BP  \
# 0   31.531  5.500  1.308    2.143  ...   0.014  3.978  17.081    6.395
# 1   27.992  6.473  1.357    1.952  ...   0.000  3.378  14.215    7.040
# 2   25.915  6.770  1.495    1.881  ...   0.000  5.841  15.057    6.550
# 3   18.776  5.773  1.688    1.927  ...   0.000  2.237  14.247    5.598
# 4   18.481  5.052  1.384    2.815  ...   0.000  3.537  14.088    5.844
#
#    TCEAL2  RUFY3  FGFRL1  CCNG2  LOC646762  Age
# ...

# %% [markdown]
# ### Splits

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler

np.random.RandomState(0)

n_show = min(len(predictor_names),12)

X = data[predictor_names]
y = data['Age']


X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25, random_state=0)

Y = y[:, np.newaxis]
Y_train = Y_train[:, np.newaxis]
Y_test = Y_test[:, np.newaxis]

print("X,y Shapes:", X.shape, Y.shape)
print("X,y Train Shapes:", X_train.shape, Y_train.shape)
print("X,y Test Shapes:", X_test.shape, Y_test.shape)
print(len(predictor_names))
# Out:
# X,y Shapes: (133, 17999) (133, 1)
# X,y Train Shapes: (99, 17999) (99, 1)
# X,y Test Shapes: (34, 17999) (34, 1)
# 17999

# %%
X.dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
X.head()
# Out:
#    COL8A2  KRT38  PRKAB2   GLDN   EAF2  LOC644936  ABHD16A   RPL35A    SQLE  \
# 0   7.227  0.000   8.222  0.019  0.192      0.676    9.782  358.296  13.593
# 1  22.211  0.101   6.796  0.052  0.215      0.550    9.963  268.634   9.426
# 2  23.603  0.000   8.065  0.000  0.137      0.703   13.289  355.606   8.232
# 3  14.669  0.000   8.190  0.075  0.387      0.531   13.264  365.623   9.399
# 4   4.593  0.018   6.608  0.011  0.507      0.360   11.149  308.585  11.375
#
#     CGB8  ...  C11orf54  ADCY8     MAP4  FLJ12825   DNPEP   THBS3  PCDHA5  \
# 0  1.490  ...     3.710  0.010   78.873     0.237  17.070  10.862   0.114
# 1  0.538  ...     1.801  0.035   94.440     0.060  13.813  13.042   0.073
# 2  1.421  ...     3.005  0.020  101.014     0.000  16.896  16.748   0.008
# 3  2.048  ...     2.627  0.012   92.053     0.000  17.274  16.073   0.037
# 4  2.592  ...     2.367  0.012   85.270     0.265  14.020  10.881   0.105
#
#    KCNQ5  TMEM121  NDUFS8
# 0  5.991    0.222  34.617
# ...

# %% [markdown]
# ### Estandarización

# %%
print("\nBefore Standardization")
fig, axes = plt.subplots(figsize=(16,3*int(np.ceil(n_show/6))),nrows=int(np.ceil(n_show/6)), ncols=6)
for i, column in enumerate(predictor_names[:n_show]):
      sns.distplot(X_train[column],ax=axes[i//6,i%6])
      axes[i//6,i%6].set_xlabel("")
      axes[i//6,i%6].set_title(column)
fig.tight_layout()
plt.show()

scaler = StandardScaler()
#scaler = RobustScaler()

#Z = X-mu/sigma

X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

scaler.fit(X_train[predictor_names])
X_train_scaled[predictor_names] = scaler.transform(X_train_scaled[predictor_names])
X_test_scaled[predictor_names] = scaler.transform(X_test_scaled[predictor_names])

print("\nAfter Standardization")
fig, axes = plt.subplots(figsize=(16,3*int(np.ceil(n_show/6))),nrows=int(np.ceil(n_show/6)), ncols=6)
for i, column in enumerate(predictor_names[:n_show]):
      sns.distplot(X_train_scaled[column],ax=axes[i//6,i%6])
      axes[i//6,i%6].set_xlabel("")
      axes[i//6,i%6].set_title(column)
fig.tight_layout()
plt.show()
# Out:
# Before Standardization
# After Standardization

# %%
print("\nResponse Standardization")
yscaler = StandardScaler()
fig, axes = plt.subplots(figsize=(16,3),nrows=1, ncols=2)
sns.distplot(Y_train,ax=axes[0])

yscaler.fit(Y_train)
Y_train_scaled = yscaler.transform(Y_train,copy=True)
Y_test_scaled = yscaler.transform(Y_test,copy=True)
sns.distplot(Y_train_scaled,ax=axes[1])
axes[0].set_xlabel('Age')
axes[1].set_xlabel('Age')
fig.tight_layout()
plt.show()
# Out:
# Response Standardization

# %% [markdown]
# ## El Regresor Lineal

# %%
from sklearn.metrics import r2_score

def mae(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute error (MAE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.abs(error).mean(), 4)


def mse(targets, predictions) -> float:
    """
    Calculo de la metrica: mean squared error (MSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round((error ** 2).mean(), 4)


def rmse(targets, predictions) -> float:
    """
    Calculo de la metrica: root mean squared error (RMSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.sqrt((error ** 2).mean()), 4)


# b) Percentage errors

def mape(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute percentage error (MAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets

    if any(x == 0 for x in targets):
        return np.inf
    else:
        return round(np.abs(error / targets).mean(),4)


def maape(targets, predictions) -> float:
    """
    Calculo de la metrica:  mean arctangent percentage error  (MAAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """

    error = predictions - targets

    if any((x, y) == (0, 0) for x, y in zip(predictions, targets)):
        return np.inf

    else:
        return round(np.arctan(np.abs(error / targets)).mean(),4)


def wmape(targets, predictions) -> float:
    """
    Calculo de la metrica:  weighted mean absolute percentage error (WMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.sum(targets)

    if sum_values == 0:
        return np.inf
    else:
        return round(np.abs(error).sum() / sum_values,4)


def mmape(targets, predictions) -> float:
    """
    Calculo de la metrica: modified mean absolute percentage error (MMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = np.abs(predictions - targets)
    denom = 1 + np.abs(targets)

    return round(np.mean(error / denom),4)


def smape(targets, predictions) -> float:
    """
    Calculo de la metrica: symmetric mean absolute percentage error (SMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.abs(predictions) + np.abs(targets)

    if any(x == 0 for x in sum_values):
        return np.inf

    else:
        return round(2 * np.mean(np.abs(error) / sum_values),4)

def summary_metrics(df) -> pd.DataFrame:
    """
    Aplicar las distintas metricas definidas
    :param df:  dataframe con las columnas: ['y','yhat']
    :return: dataframe con las metricas especificadas
    """
    df_result = pd.DataFrame()

    y_true = df['y']
    y_pred = df['yhat']

    df_result['mae'] = [round(mae(y_true, y_pred), 4)]
    df_result['mse'] = [round(mse(y_true, y_pred), 4)]
    df_result['rmse'] = [round(rmse(y_true, y_pred), 4)]

    df_result['mape'] = [round(mape(y_true, y_pred), 4)]
    df_result['maape'] = [round(maape(y_true, y_pred), 4)]
    df_result['wmape'] = [round(wmape(y_true, y_pred), 4)]
    df_result['mmape'] = [round(mmape(y_true, y_pred), 4)]
    df_result['smape'] = [round(smape(y_true, y_pred), 4)]

    df_result['r2'] = [round(r2_score(y_true,y_pred),4)]

    return df_result

# %%
X_train = X_train_scaled.copy()
X_test = X_test_scaled.copy()

y_train = Y_train.copy()
y_test = Y_test.copy()

print(f'numero de filas train set: {len(X_train)}')
print(f'numero de filas test set: {len(X_test)}')
# Out:
# numero de filas train set: 99
# numero de filas test set: 34

# %%
clf = LinearRegression().fit(X_train, y_train)

y_predict_train_clf = clf.predict(X_train)
enc_pred_train = lab_enc.fit_transform(y_predict_train_clf)
y_predict_train_clf = enc_pred_train
print('y_predict_train_clf = ',y_predict_train_clf)

y_predict_test_clf = clf.predict(X_test)
enc_pred_test = lab_enc.fit_transform(y_predict_test_clf)
y_predict_test_clf = enc_pred_test
print('y_predict_test_clf = ',y_predict_test_clf)
# Out:
# y_predict_train_clf =  [11 43 29 69 32 72 44 36 30 54 28 18 70 39 45 38 86  8  6 80 49 81 88 85
#  59  0 41 90 50 12 80 22 78 19 71  4 26 20 58 25 21 31 10 62 17 14 89 33
#  53 23 76 51 91 79 35 84 16 85  2 43 82 60 87 74 93 66 46 15 63 47 64 61
#  13 48 56 92 34 65  5 77  9 24 83 57 37 42  7 73 55 70 27  1 75 68 40 86
#  52  3 67]
# y_predict_test_clf =  [27  3 30  7 32 28 24 33 15 21 22 29 23 26 10  2 25 18  6 12 17  5 31 11
#  20 13  9  4 19  0  1 16  8 14]

# %% [markdown]
# ## Principal Component Analysis en el Regresor Lineal

# %%
n = 30

columns=[]
for i in range(n): 
    columns.append('PC'+str(i+1))

pca = PCA(n_components=n) #Modelo, se tomarán n-componentes, es decir, se tomarán n variables para reducir la dimensión
principalComponents = pca.fit_transform(X) #fit del modelo

principalDataframe = pd.DataFrame(data = principalComponents, columns = columns)
principalDataframe.head()
# Out:
#            PC1          PC2          PC3          PC4          PC5  \
# 0   212.450080   706.379156 -2791.424311  1859.284504  -616.666665
# 1   283.646574  1084.435561   544.374290 -1253.833090  -725.828066
# 2 -1153.807020   -42.979679  1346.232137  -294.678118  -146.743173
# 3  -903.019730  2230.754646   -92.643351 -1544.549761   828.044404
# 4   211.793890  3040.699322  -307.162163   299.379162 -1227.096916
#
#            PC6          PC7          PC8          PC9        PC10  ...  \
# 0   265.826557   299.614129  -403.706756   530.435498 -609.702257  ...
# 1  -180.866209  1690.521373   696.443524  -617.069258  293.869783  ...
# 2   815.542223  1120.448143   183.924429 -1007.276063 -305.885978  ...
# 3  1615.685398   242.815598     9.454891   900.555280  387.800216  ...
# 4  1409.441052  -182.559843  1252.756355  -878.907372 -307.888403  ...
#
#          PC21        PC22        PC23        PC24        PC25        PC26  \
# ...

# %%
df_reducido = pd.concat([principalDataframe, pd.DataFrame(Y, columns=['Age'])],axis = 1)
df_reducido.head()
# Out:
#            PC1          PC2          PC3          PC4          PC5  \
# 0   212.450080   706.379156 -2791.424311  1859.284504  -616.666665
# 1   283.646574  1084.435561   544.374290 -1253.833090  -725.828066
# 2 -1153.807020   -42.979679  1346.232137  -294.678118  -146.743173
# 3  -903.019730  2230.754646   -92.643351 -1544.549761   828.044404
# 4   211.793890  3040.699322  -307.162163   299.379162 -1227.096916
#
#            PC6          PC7          PC8          PC9        PC10  ...  \
# 0   265.826557   299.614129  -403.706756   530.435498 -609.702257  ...
# 1  -180.866209  1690.521373   696.443524  -617.069258  293.869783  ...
# 2   815.542223  1120.448143   183.924429 -1007.276063 -305.885978  ...
# 3  1615.685398   242.815598     9.454891   900.555280  387.800216  ...
# 4  1409.441052  -182.559843  1252.756355  -878.907372 -307.888403  ...
#
#          PC22        PC23        PC24        PC25        PC26        PC27  \
# ...

# %%
#Se utilizan las componentes proyectadas
from sklearn import preprocessing
from sklearn import utils
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

X = df_reducido[columns]
Y = df_reducido['Age']

#Se normaliza con Standard Scaler
X = StandardScaler().fit_transform(X)

#Se crean los conjuntos de entrenamiento y test desde los conjuntos definidos anteriormente
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state = 2)

# %%
pd.DataFrame(X,columns=columns)
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    0.079689  0.334793 -1.589696  1.092664 -0.464373  0.217033  0.307698
# 1    0.106395  0.513975  0.310017 -0.736852 -0.546576 -0.147667  1.736131
# 2   -0.432790 -0.020370  0.766670 -0.173176 -0.110503  0.665846  1.150678
# 3   -0.338720  1.057280 -0.052760 -0.907701  0.623549  1.319120  0.249367
# 4    0.079443  1.441159 -0.174927  0.175939 -0.924051  1.150732 -0.187485
# ..        ...       ...       ...       ...       ...       ...       ...
# 128  0.269986  1.081879  0.426250  0.060448 -0.250194 -0.644408  0.758007
# 129 -0.005197  0.488901 -0.749002  0.455405 -0.164838  0.418233 -0.586093
# 130  0.054489  0.979994 -0.182629 -0.002596 -1.022704 -0.134718 -0.314552
# 131 -1.716110 -0.488521 -1.981622  0.859410  0.353843 -0.469180  0.972069
# 132 -0.032201  0.163100 -2.895815  1.995458 -0.351573  0.260984  1.448309
#
#           PC8       PC9      PC10  ...      PC21      PC22      PC23  \
# ...

# %%
clf = LinearRegression().fit(X_train, Y_train)

Y_predict_train_pca = clf.predict(X_train)
enc_pred_train = lab_enc.fit_transform(Y_predict_train_pca)
Y_predict_train_pca = enc_pred_train
print('Y_predict_train_pca = ',Y_predict_train_pca)

Y_predict_test_pca = clf.predict(X_test)
enc_pred_pca = lab_enc.fit_transform(Y_predict_test_pca)
Y_predict_test_pca = enc_pred_pca
print('Y_predict_test_pca = ',Y_predict_test_pca)
# Out:
# Y_predict_train_pca =  [ 3 81 57 74 44 49 66 61 12 35 84 70 10 65 16 47 83 69 20 27 18 58 53 26
#   0 34 37 82 87 75 11 51 31 29 14 38 73  5  2 25 76 17  6 28  1 86 43 48
#  52 56 36  7 67 15 55 50 60 59 46  4 19  9 23 85 39 78 24 22 77 63 32 13
#  72 79 88 40 41 64  8 62 71 30 21 80 42 68 54 45 33]
# Y_predict_test_pca =  [16  7 30 19 20 23 31 10  8 34 37 40 41 33 26  1  0 28 32  5 36 25  4  2
#  21  9 17 18 38  6 22 27 11 42 15 14  3 13 24 43 35 29 12 39]

# %%
#Varianzas por n-componentes
percent_variance = np.round(pca.explained_variance_ratio_, decimals =3)

plt.figure(figsize=(15,7))
plt.bar(x= range(1,n+1), height=percent_variance, tick_label=columns)
plt.xticks(x= range(1,n+1), rotation='vertical')
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %%
# Gráfico de Varianza acumulada entre las n-componentes
percent_variance_cum = np.cumsum(percent_variance)

plt.figure(figsize=(15,7))
plt.bar(x= range(1,n+1), height=percent_variance_cum, tick_label=columns)
plt.xticks(x= range(1,n+1), rotation='vertical')
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component Cumsum')
plt.title('PCA Scree Plot')
plt.show()

# %%
print(percent_variance_cum[-1])
# Out:
# 0.9720000000000003

# %% [markdown]
# ## Comparación

# %%
y_test = [elem for elem in y_test[:,0]]

# %%
pd.concat([summary_metrics(pd.DataFrame(data={'y':y_test, 'yhat':y_predict_test_clf})),summary_metrics(pd.DataFrame(data={'y':Y_test, 'yhat':Y_predict_test_pca}))], keys=['LinReg model', 'LinReg model + PCA'])
# Out:
#                           mae        mse     rmse    mape   maape   wmape  \
# LinReg model       0  40.6176  2108.5000  45.9184  0.6830  0.5899  0.7111
# LinReg model + PCA 0  31.6364  1381.7273  37.1716  0.6012  0.5265  0.6132
#
#                        mmape   smape      r2
# LinReg model       0  0.6645  1.0836 -1.4741
# LinReg model + PCA 0  0.5826  0.8816 -0.6184

# %% [markdown]
# Un modelo lineal ordinario obtiene un RMSE (en escala original) de
#
# *   TEST: 45.93 (usando solo el modelo de Regresión Lineal)
# *   TEST: 37.18 (usando PCA)
#
# Si en cambio nos interesa el error relativo y medimos el MAPE
#
# *   TEST: 0.68 (usando solo el modelo de Regresión Lineal)
# *   TEST: 0.60 (usando PCA)

# %% [markdown]
# # Problema 3

# %% [markdown]
# Se ha creado un conjunto de datos sintéticos usando `make_regression` de `sklearn`.

# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

from sklearn import datasets

import warnings
warnings.filterwarnings("ignore")

from numpy import linalg
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=7000, n_features=150, n_informative=150, shuffle=False, random_state=0)

# Estandarizamos el target
m = np.mean(y)
s = np.std(y)
z = (y-m)/s

data = pd.DataFrame(X)
data['target'] = z
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  0.950088
# 1 -0.068242  1.713343 -0.744755 -0.826439 -0.098453 -0.663478  1.126636
# 2 -1.306527  1.658131 -0.118164 -0.680178  0.666383 -0.460720 -1.334258
# 3 -1.054628  0.820248  0.463130  0.279096  0.338904  2.021044 -0.468864
# 4 -1.550429  0.417319 -0.944368  0.238103 -1.405963 -0.590058 -0.110489
#
#           7         8         9  ...       141       142       143       144  \
# 0 -0.151357 -0.103219  0.410599  ...  0.439392  0.166673  0.635031  2.383145
# 1 -1.079932 -1.147469 -0.437820  ... -0.481027  2.303917 -1.060016 -0.135950
# 2 -1.346718  0.693773 -0.159573  ... -1.159421 -0.085931  0.194293  0.875833
# 3 -2.201441  0.199300 -0.050604  ...  0.439043 -0.219541 -1.084037  0.351780
# 4 -1.660700  0.115148 -0.379148  ... -1.140196  1.754986 -0.132988 -0.765702
#
#         145       146       147       148       149    target
# ...

# %%
predictor_names = data.columns[:150]
n_show = min(len(predictor_names),50)

corrmat = data[predictor_names[:n_show]].corr()
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corrmat, vmax=.9, square=True, ax=ax, cmap='PiYG_r')
ax.set_title("Correlación Lineal Predictores vs Predictores")
plt.show()

# %%
from sklearn.metrics import r2_score

def mae(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute error (MAE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.abs(error).mean(), 4)


def mse(targets, predictions) -> float:
    """
    Calculo de la metrica: mean squared error (MSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round((error ** 2).mean(), 4)


def rmse(targets, predictions) -> float:
    """
    Calculo de la metrica: root mean squared error (RMSE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    return round(np.sqrt((error ** 2).mean()), 4)


# b) Percentage errors

def mape(targets, predictions) -> float:
    """
    Calculo de la metrica: mean absolute percentage error (MAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets

    if any(x == 0 for x in targets):
        return np.inf
    else:
        return round(np.abs(error / targets).mean(),4)


def maape(targets, predictions) -> float:
    """
    Calculo de la metrica:  mean arctangent percentage error  (MAAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """

    error = predictions - targets

    if any((x, y) == (0, 0) for x, y in zip(predictions, targets)):
        return np.inf

    else:
        return round(np.arctan(np.abs(error / targets)).mean(),4)


def wmape(targets, predictions) -> float:
    """
    Calculo de la metrica:  weighted mean absolute percentage error (WMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.sum(targets)

    if sum_values == 0:
        return np.inf
    else:
        return round(np.abs(error).sum() / sum_values,4)


def mmape(targets, predictions) -> float:
    """
    Calculo de la metrica: modified mean absolute percentage error (MMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = np.abs(predictions - targets)
    denom = 1 + np.abs(targets)

    return round(np.mean(error / denom),4)


def smape(targets, predictions) -> float:
    """
    Calculo de la metrica: symmetric mean absolute percentage error (SMAPE)
    :param targets: valor real
    :param predictions: valor estimado
    :return: valor de la metrica
    """
    error = predictions - targets
    sum_values = np.abs(predictions) + np.abs(targets)

    if any(x == 0 for x in sum_values):
        return np.inf

    else:
        return round(2 * np.mean(np.abs(error) / sum_values),4)

def summary_metrics(df) -> pd.DataFrame:
    """
    Aplicar las distintas metricas definidas
    :param df:  dataframe con las columnas: ['y','yhat']
    :return: dataframe con las metricas especificadas
    """
    df_result = pd.DataFrame()

    y_true = df['y']
    y_pred = df['yhat']

    df_result['mae'] = [round(mae(y_true, y_pred), 4)]
    df_result['mse'] = [round(mse(y_true, y_pred), 4)]
    df_result['rmse'] = [round(rmse(y_true, y_pred), 4)]

    df_result['mape'] = [round(mape(y_true, y_pred), 4)]
    df_result['maape'] = [round(maape(y_true, y_pred), 4)]
    df_result['wmape'] = [round(wmape(y_true, y_pred), 4)]
    df_result['mmape'] = [round(mmape(y_true, y_pred), 4)]
    df_result['smape'] = [round(smape(y_true, y_pred), 4)]

    df_result['r2'] = [round(r2_score(y_true,y_pred),4)]

    return df_result

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn import utils

noises = [0.1,5,10,50,100,250,500,750,1000,5000]

d = dict()

for noise in noises:
    X, y = make_regression(n_samples=7000, n_features=150, n_informative=150, noise=noise, shuffle=False, random_state=0)

    # Estandarizamos el target
    m = np.mean(y)
    s = np.std(y)
    z = (y-m)/s

    data = pd.DataFrame(X)
    data['target'] = z

    X_train, X_test, y_train, y_test = train_test_split(X, z, test_size=0.33, random_state=0)

    print(f'numero de filas train set: {len(X_train)}')
    print(f'numero de filas test set: {len(X_test)}')

    # %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    # MODELO DE REGRESION LINEAL

    linreg_model = LinearRegression().fit(X_train,y_train)
    y_pred = linreg_model.predict(X_test)
    a = summary_metrics(pd.DataFrame(data={'y':y_test, 'yhat':y_pred}))


    # %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    # MODELO DE REGRESION LINEAL CON PCA

    pca = PCA(n_components=50)
    principalComponents = pca.fit_transform(X)

    l = []
    for i in range(50):
        uwu = 'PC'+str(i+1)
        l.append(uwu)

    principalDataframe = pd.DataFrame(data = principalComponents, columns = l)

    df_reducido = pd.concat([principalDataframe, pd.DataFrame(z)],axis = 1)

    df_reducido = df_reducido.rename(columns={0: "target"})

    #Se utilizan las componentes proyectadas
    X = df_reducido[l]
    Y = df_reducido['target']

    #Se crean los conjuntos de entrenamiento y test desde los conjuntos definidos anteriormente
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state = 0)

    linreg_model = LinearRegression().fit(X_train, Y_train)
    Y_pred = linreg_model.predict(X_test)
    b = summary_metrics(pd.DataFrame(data={'y':Y_test, 'yhat':Y_pred}))


    # COMPARACION ENTRE AMBOS MODELOS
    c = pd.concat([a,b], keys=['LinReg model', 'LinReg model + PCA'])
    c['noise'] = noise

    d[str(noise)] = c.T
# Out:
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310
# numero de filas train set: 4690
# numero de filas test set: 2310

# %% [markdown]
# ## Comparación

# %%
df = pd.concat([v for k,v in d.items()],axis=1).T
df.reset_index(level=0,inplace=True)
df.index = pd.RangeIndex(len(df.index))
df.index = range(len(df.index))
df.head()
# Out:
#               level_0     mae     mse    rmse    mape   maape    wmape  \
# 0        LinReg model  0.0001  0.0000  0.0001  0.0005  0.0005  -0.0037
# 1  LinReg model + PCA  0.6495  0.6559  0.8099  2.4015  0.7075 -21.5953
# 2        LinReg model  0.0055  0.0000  0.0069  0.0473  0.0243  -0.1835
# 3  LinReg model + PCA  0.6632  0.6690  0.8179  3.7808  0.7212 -22.0803
# 4        LinReg model  0.0110  0.0002  0.0139  0.0647  0.0441  -0.3675
#
#     mmape   smape      r2  noise
# 0  0.0001  0.0005  1.0000    0.1
# 1  0.3566  1.1555  0.3342    0.1
# 2  0.0034  0.0258  1.0000    5.0
# 3  0.3617  1.1993  0.3209    5.0
# 4  0.0068  0.0479  0.9998   10.0

# %%
def row_style(row):
    if row.noise != 'Total':
        if row.noise==0.1:
            return pd.Series('background-color: red', row.index)
        elif row.noise==5.0:
            return pd.Series('background-color: green', row.index)
        elif row.noise==10.0:
            return pd.Series('background-color: red', row.index)
        elif row.noise==50.0:
            return pd.Series('background-color: green', row.index)
        elif row.noise==100.0:
            return pd.Series('background-color: red', row.index)
        elif row.noise==250.0:
            return pd.Series('background-color: green', row.index)
        elif row.noise==500.0:
            return pd.Series('background-color: red', row.index)
        elif row.noise==750.0:
            return pd.Series('background-color: green', row.index)
        elif row.noise==1000.0:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

df.style.apply(row_style, axis=1)
# Out:
# <style  type="text/css" >
# ...
